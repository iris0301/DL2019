# %%
import json
import os 
import urllib 
import re 
import requests 
import tweepy           
import urllib 
from textblob import TextBlob 

        
     
consumerKey =  "2XaGuf5hIS0K5l72OoYxLzklz"
consumerSecret = "LeJVqoOgOwLVE2AedE1WiFmEGG6ps1fhX6XMgm3qVBCyTO231u"
accessToken = "3328579866-cxEFxLWIz7KiHB9vvTNhplZlMOK5hbBBsSnfoNl"
accessTokenSecret = "xrY0e5mF6nk3WLamxkBlBxabb42PYrgJ3kurkEEcuvgxl"

url = 'http://www.sentiment140.com/api/bulkClassifyJson?appid=yunyun_yao@brown.edu'

   
auth = tweepy.OAuthHandler(consumerKey, consumerSecret)  
auth.set_access_token(accessToken, accessTokenSecret)  
  

api = tweepy.API(auth, wait_on_rate_limit=True)  

places = api.geo_search(query="USA", granularity="country")
place_id = places[0].id

i=0
try:
    tweet_obj_list=[]
    #search by location
    for tweet in tweepy.Cursor(api.search,q="place:%s" % place_id,tweet_mode='extended').items(10000):  
    #for tweet in tweepy.Cursor(api.search,q = 'Donald Trump',tweet_mode='extended').items(10000): 
    #Search by key word
        tweet_obj = []
        check_retweet = 1
        i = i+1
        print(i)
        a = tweet.full_text
        b = a[:4]
        check_retweet = int(b == 'RT @')
        #print(check_retweet)
                
        if check_retweet == 0 :   
            content = tweet.full_text
            content = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", content).split()) 
            analysis = TextBlob(content) 
                # set sentiment 
#             if analysis.sentiment.polarity > 0: 
#                 sentiment = 'positive'
#             elif analysis.sentiment.polarity == 0: 
#                 sentiment = 'neutral'
#             else: 
#                 sentiment = 'negative'
            
    
            values = {'data': [{'text': content}]} 
            data = json.dumps(values)
            response = urllib.request.urlopen(url, data=data.encode("utf-8"))
            page = response.read()

            json_obj = json.loads(page)
            sentiment140 = json_obj['data'][0]['polarity']
            
            tweet_obj.append({
                'id': tweet.id,
                'text': tweet.full_text,
                'sentiment': analysis.sentiment.polarity,
                'user_id': tweet.user.id,
                'name': tweet.user.screen_name,
                'location': tweet.user.location,
                'retweet count': tweet.retweet_count,
                'favorite count': tweet.favorite_count,
                'time': tweet.created_at.strftime('%m/%d/%Y %H:%M:%S'),
                'sentiment140': sentiment140
                })
            #print(tweet.created_at.strftime('%m/%d/%Y %H:%M:%S'))
            tweet_obj_list.append(tweet_obj)
        else:
            print('retweet')
except:
    print('error on: ')
# Out:
# 1
# 11/17/2019 22:54:41
# [{'id': 1196200009336799236, 'text': 'I know im getting older cuz kids outside without a coat on gets me upset 😂', 'sentiment': 0.08333333333333333, 'user_id': 720086164321873924, 'name': 'highpotiental', 'location': 'Little Rock, AR', 'retweet count': 0, 'favorite count': 0, 'time': '11/17/2019 22:54:41', 'sentiment140': 0}]
# 2
# 11/17/2019 22:54:41
# [{'id': 1196200009101987842, 'text': '@Bengals WTF', 'sentiment': -0.5, 'user_id': 2165128950, 'name': 'JeremyDuit86', 'location': 'Sunrise, FL', 'retweet count': 0, 'favorite count': 0, 'time': '11/17/2019 22:54:41', 'sentiment140': 2}]
# 3
# 11/17/2019 22:54:41
# [{'id': 1196200009038884864, 'text': '#Busch4Harvick #sweepstakes https://t.co/iyd2udll69', 'sentiment': 0.0, 'user_id': 12100272, 'name': 'viclen1954', 'location': 'Pacific Wonderland USA', 'retweet count': 0, 'favorite count': 0, 'time': '11/17/2019 22:54:41', 'sentiment140': 2}]
# 4
# 11/17/2019 22:54:41
# [{'id': 1196200008565100544, 'text': '@Krasiviesiski @okbuenoestabien Les quiero, pendejos 😍', 'sentiment': 0.0, 'user_id': 77116985, 'name': 'Andresvu', 'location': 'Washington, DC', 'retweet count': 0, 'favorite count': 0, 'time': '11/17/2019 22:54:41', 'sentiment140': 2}]
# 5
# 11/17/2019 22:54:40
# [{'id': 1196200008141475841, 'text': 'i say airpods my mom says airplugs', 'sentiment': 0.0, 'user_id': 68243446, 'name': 'biancatamura', 'location': '', 'retweet count': 0, 'favorite count': 0, 'time': '11/17/2019 22:54:40', 'sentiment140': 2}]
# 6
# 11/17/2019 22:54:40
# [{'id': 1196200008053342209, 'text': "Visit tonight for 'Acuña Acuna ’, a live one person comedy show based on Erick Acuña 's real life as a Peruvian Latino living in America.\n\nTonight at 8pm https://t.co/fGkOoS3S99", 'sentiment': 0.16818181818181818, 'user_id': 14707059, 'name': 'bigimprov', 'location': 'Baltimore, MD', 'retweet count': 0, 'favorite count': 0, 'time': '11/17/2019 22:54:40', 'sentiment140': 4}]
# 7
# 11/17/2019 22:54:40
# [{'id': 1196200007231250432, 'text': 'We eating Italian tonight baby https://t.co/2rlwemBWsh', 'sentiment': 0.0, 'user_id': 935465906339069953, 'name': 'BrookeBenz_', 'location': 'Twerklandia', 'retweet count': 0, 'favorite count': 0, 'time': '11/17/2019 22:54:40', 'sentiment140': 2}]
# 8
# 11/17/2019 22:54:40
# [{'id': 1196200006920949760, 'text': '@NRA Civil rights!?!?😆😆😆😆😆😆😆😆😆😆😆😆😆😆😆😆😆😆😆', 'sentiment': 0.0, 'user_id': 917467316, 'name': 'AlisaHilde', 'location': 'Fargo, North Dakota', 'retweet count': 0, 'favorite count': 0, 'time': '11/17/2019 22:54:40', 'sentiment140': 2}]
# 9
# 11/17/2019 22:54:40
# [{'id': 1196200006484725765, 'text': 'Not bad for a RB https://t.co/bl29nHma4Q', 'sentiment': 0.3499999999999999, 'user_id': 1230401210, 'name': '_collinnnn', 'location': '', 'retweet count': 0, 'favorite count': 0, 'time': '11/17/2019 22:54:40', 'sentiment140': 2}]
# 10
# 11/17/2019 22:54:40
# [{'id': 1196200004710367234, 'text': '@shipmate68 @kricklys @KAG1776MAGA @AngelWarrior321 @AtF_GoGo81olds @beachfront1962 @Brooke_Kelly87 @cockyrascal @ReallyKW @hoppinmama5 @JoeTeedoff @KnarleyC @LakeMonsterCL @Michael3_t @RL9631 @sapiofox @SheriffRuth @STEWL6 @Teriface73 @Tpeee60 @tsunami_eric Following', 'sentiment': 0.0, 'user_id': 3323270594, 'name': 'sandyb432', 'location': 'Mohave Valley, AZ', 'retweet count': 0, 'favorite count': 0, 'time': '11/17/2019 22:54:40', 'sentiment140': 2}]

# %%
with open('emoji/emoji_final_join.json',encoding='utf-8') as f: 
    emoji_list = json.load(f)


def check_emoji(text):
    all_emoji = []
    polarity = 0
    
    for ele in emoji_list:
        if ele['emoji'] in text:
            all_emoji.append(ele['emoji'])
            polarity += ele['polarity']
    emojis = ''.join(all_emoji)
    
    if len(all_emoji) != 0:
        polarity = round(polarity/len(all_emoji))
        
    return emojis, polarity
            


for element in tweet_obj_list:
    emojis,polarity = check_emoji(element[0]['text'])
    element[0]['emoji'] = emojis
    element[0]['emoji_polarity'] = polarity

# %%
## writes to this  
with open('test.json', 'w', encoding='utf-8') as outfile:   
    json.dump(tweet_obj_list, outfile, ensure_ascii=False, indent=4, separators=(',', ': '))

# %%
with open('test.json',encoding='utf-8') as f:
    line = json.load(f)
