# %%
import json
import os 
import urllib 
import re 
import requests 
import tweepy           
import datetime
from time import gmtime, strftime
from textblob import TextBlob 
        
     
consumerKey =  "2XaGuf5hIS0K5l72OoYxLzklz"
consumerSecret = "LeJVqoOgOwLVE2AedE1WiFmEGG6ps1fhX6XMgm3qVBCyTO231u"
accessToken = "3328579866-cxEFxLWIz7KiHB9vvTNhplZlMOK5hbBBsSnfoNl"
accessTokenSecret = "xrY0e5mF6nk3WLamxkBlBxabb42PYrgJ3kurkEEcuvgxl"
  
   
auth = tweepy.OAuthHandler(consumerKey, consumerSecret)  
auth.set_access_token(accessToken, accessTokenSecret)  
  

api = tweepy.API(auth, wait_on_rate_limit=True)  

places = api.geo_search(query="USA", granularity="country")
place_id = places[0].id

i=0
try:
    tweet_obj_list=[]
    #search by location
    for tweet in tweepy.Cursor(api.search,q="place:%s" % place_id,tweet_mode='extended').items(50):  
    #for tweet in tweepy.Cursor(api.search,q = 'Donald Trump',tweet_mode='extended').items(50): 
    #Search by key word
        tweet_obj = []
        check_retweet = 1
        i = i+1
        print(i)
        a = tweet.full_text
        b = a[:4]
        check_retweet = int(b == 'RT @')
        #print(check_retweet)
                
        if check_retweet == 0 :   
            content = tweet.full_text
            content = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", content).split()) 
            analysis = TextBlob(content) 
                # set sentiment 
            if analysis.sentiment.polarity > 0: 
                sentiment = 'positive'
            elif analysis.sentiment.polarity == 0: 
                sentiment = 'neutral'
            else: 
                sentiment = 'negative'
            
            
            tweet_obj.append({
                'id': tweet.id,
                'text': tweet.full_text,
                'sentiment': sentiment,
                'user_id': tweet.user.id,
                'name': tweet.user.screen_name,
                'location': tweet.user.location,
                'retweet count': tweet.retweet_count,
                'favorite count': tweet.favorite_count,
                'time': tweet.created_at.strftime('%m/%d/%Y %H:%M:%S'),
                
                })
            print(tweet_obj)
            tweet_obj_list.append(tweet_obj)
        else:
            print('retweet')
except:
    print('error on: ')
# Out:
# 1
# [{'id': 1193408174331584514, 'text': '@TheSlanderGawwd vs @CashNastyGaming https://t.co/52QII7bKMh', 'sentiment': 'neutral', 'user_id': 190093478, 'name': 'SeanathonOAK', 'location': 'Star Labs', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:55'}]
# 2
# [{'id': 1193408172649660416, 'text': 'All the feels! 💖💞💕💞💗💕💗 https://t.co/fIG499uZwe', 'sentiment': 'neutral', 'user_id': 74284365, 'name': 'TweetyLolita', 'location': 'San Francisco', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:55'}]
# 3
# [{'id': 1193408172515643394, 'text': 'Y’all hear em 🗣 https://t.co/AOPrEkVrTg', 'sentiment': 'neutral', 'user_id': 965406583911014403, 'name': 'GorillaPimpin_', 'location': 'Memphis, TN', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:55'}]
# 4
# [{'id': 1193408172440084481, 'text': 'Bitch confused about what??? you know what you said 🤦🏻\u200d♀️🤦🏻\u200d♀️ https://t.co/x56ygqXOtb', 'sentiment': 'negative', 'user_id': 1235875796, 'name': 'KahliTherese', 'location': '', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:55'}]
# 5
# [{'id': 1193408172255367174, 'text': '@Moralesti_ Pero no hice nada 😪', 'sentiment': 'neutral', 'user_id': 935702823676686336, 'name': 'manuelittooo', 'location': '', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:55'}]
# 6
# [{'id': 1193408172230369280, 'text': 'all i know is meek lol I really love him !', 'sentiment': 'positive', 'user_id': 3046988397, 'name': 'Envyy_monii', 'location': '', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:55'}]
# 7
# [{'id': 1193408172142321665, 'text': 'I’m hungry dab', 'sentiment': 'neutral', 'user_id': 2804677057, 'name': 'skubacece', 'location': 'Indianapolis, IN', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:55'}]
# 8
# [{'id': 1193408170942746624, 'text': 'im not finna walk fast its over', 'sentiment': 'positive', 'user_id': 2615773406, 'name': 'cousincarson', 'location': 'Indiana, USA', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:55'}]
# 9
# [{'id': 1193408170703458304, 'text': '@KC_Sass But you are... 👍🏽💯', 'sentiment': 'neutral', 'user_id': 1015752379180855296, 'name': 'amano5756', 'location': 'Washington, USA', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:55'}]
# 10
# [{'id': 1193408170636595200, 'text': 'Ok me https://t.co/wfvJX3Bjap', 'sentiment': 'positive', 'user_id': 737351911, 'name': 'ktholdss', 'location': 'NYC/Nashville', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:54'}]
# 11
# [{'id': 1193408169629945857, 'text': 'I needed this https://t.co/Ub2fIZ4QGJ', 'sentiment': 'neutral', 'user_id': 1561611884, 'name': 'AlexisRenae__', 'location': 'San Antonio, TX', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:54'}]
# 12
# [{'id': 1193408169285808130, 'text': 'These pregnancy hormones make me want to super glue myself to Justin 😩', 'sentiment': 'positive', 'user_id': 2985071645, 'name': 'hannmos', 'location': 'Oceanside, CA', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:54'}]
# 13
# [{'id': 1193408169160183808, 'text': 'Yeah I’m drunk 😂', 'sentiment': 'negative', 'user_id': 38967598, 'name': 'juiceandbooze', 'location': '', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:54'}]
# 14
# [{'id': 1193408168598089728, 'text': 'update- definitely reached 100.1% tonight https://t.co/KHgUVHLtNH', 'sentiment': 'neutral', 'user_id': 700194025, 'name': 'johnronia', 'location': 'Sending 4:20 Streaks', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:54'}]
# 15
# [{'id': 1193408168107368449, 'text': 'This pulled out my heart and lung 💔😭 https://t.co/eleSk6aheI', 'sentiment': 'neutral', 'user_id': 471534622, 'name': 'JBJBorrero', 'location': 'Blue Lady ', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:54'}]
# 16
# [{'id': 1193408167457243136, 'text': '@reese_tuitele Lmaooo. EXACTLY!', 'sentiment': 'positive', 'user_id': 844755471307235329, 'name': 'KEONIIIII', 'location': 'Des Moines, IA', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:54'}]
# 17
# [{'id': 1193408166907858944, 'text': '@DeShawn_Charles the vicar of dibley', 'sentiment': 'neutral', 'user_id': 65165073, 'name': 'thecodystuart', 'location': 'Manhattan, NY', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:54'}]
# 18
# [{'id': 1193408166576279553, 'text': '@amandamarie2pt0 with?', 'sentiment': 'neutral', 'user_id': 396743617, 'name': 'rico_suave832', 'location': 'Cobb County, GA', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:54'}]
# 19
# [{'id': 1193408166387757057, 'text': '@Loka_Vijeta every other fight is a warning the first time for everything', 'sentiment': 'positive', 'user_id': 2608916616, 'name': 'MasonReact', 'location': 'United States', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:53'}]
# 20
# [{'id': 1193408166337425409, 'text': 'President Trump "not concerned" about impeachment inquiry\n\nhttps://t.co/OGnL8e5Exn', 'sentiment': 'neutral', 'user_id': 507580314, 'name': 'mgztv', 'location': 'Cary, NC', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:53'}]
# 21
# [{'id': 1193408166274510849, 'text': '@TonyRos61061426 @ademtho @Dorstic04 @FamousDerinn @Viperous agreed.', 'sentiment': 'neutral', 'user_id': 722610798795886595, 'name': 'i_AJ_', 'location': '', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:53'}]
# 22
# [{'id': 1193408166119100416, 'text': '@Sia I’m trying Sia I am, love you too.', 'sentiment': 'positive', 'user_id': 430501072, 'name': 'LykosGLWS', 'location': 'Los Angeles, CA', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:53'}]
# 23
# [{'id': 1193408165980729345, 'text': '@Dt33345 @ErikVoorhees The only thing worse than cheap money is free money. The biggest looser will be the undocumented, the mental health folks living on the street, they won’t even sign up for the help and it will be even harder for them to survive.', 'sentiment': 'positive', 'user_id': 25125231, 'name': 'AZbroker', 'location': 'Salt Lake City, UT', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:53'}]
# 24
# [{'id': 1193408165435584512, 'text': '@Manigarm That’s what I’m talking about', 'sentiment': 'neutral', 'user_id': 27385995, 'name': 'dinjiifashion', 'location': 'Houston, TX', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:53'}]
# 25
# [{'id': 1193408164944842752, 'text': 'Sikowitz’s reminds me of Mr.cruz LOL https://t.co/J9VVOwIasf', 'sentiment': 'positive', 'user_id': 3386333421, 'name': 'jackeelime', 'location': 'Dallas, TX', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:53'}]
# 26
# [{'id': 1193408164923883520, 'text': 'smells like weed in the whole back of the store and my manager really says, "ah, you sure it isn\'t just rhi smokin it up back here?" \n\nwooow', 'sentiment': 'positive', 'user_id': 700313964232609793, 'name': 'randondirty', 'location': 'with my man', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:53'}]
# 27
# [{'id': 1193408164051521537, 'text': 'Liquor may be wearing off and I’m pissed I don’t got nothing else! 😭', 'sentiment': 'neutral', 'user_id': 327057174, 'name': 'QueenJAMES_2you', 'location': 'Whereever life takes me ✈️', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:53'}]
# 28
# [{'id': 1193408163975847938, 'text': "@HopeCarr1987 I'm so sorry for your lost. My condolences to you and your family.", 'sentiment': 'negative', 'user_id': 1125501650402041856, 'name': 'SabioCatherine', 'location': '', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:53'}]
# 29
# [{'id': 1193408163736948736, 'text': 'Feminists throw water at me and Gavin in Washington DC https://t.co/PUo351bGRR', 'sentiment': 'neutral', 'user_id': 166313492, 'name': 'ololabear', 'location': 'The Heart of Dixie', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:53'}]
# 30
# [{'id': 1193408163648823296, 'text': '@Phillygirl741 Still can’t spell and you make no sense. Maybe you need to leave philly and move south where you can attend Klan meetings and meet more like minded people.', 'sentiment': 'positive', 'user_id': 1050073072336887815, 'name': 'EnsPulver1958', 'location': 'Texas, USA', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:53'}]
# 31
# [{'id': 1193408163317526528, 'text': 'i need to get contracts for what photos can &amp; cant be posted of me if we work together.', 'sentiment': 'neutral', 'user_id': 3147208070, 'name': 'iamdaej', 'location': 'traveling the world🌎', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:53'}]
# 32
# [{'id': 1193408163292205056, 'text': '@RWPUSA @realDonaldTrump What an awesome idea. So much better than jumping into the race.', 'sentiment': 'positive', 'user_id': 2474405820, 'name': 'CynthiaSchlie', 'location': 'Elverta, CA', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:53'}]
# 33
# [{'id': 1193408163225178113, 'text': '@Gusbuckets “How to remove the virus I received from watching several illegal streams”', 'sentiment': 'negative', 'user_id': 3010179550, 'name': 'EricMoranFilms', 'location': 'Chevy Chase, MD 🛩 Chicago, IL', 'retweet count': 0, 'favorite count': 1, 'time': '11/10/2019 06:00:53'}]
# 34
# [{'id': 1193408163099369473, 'text': 'Falling asleep by myself for the first time in a while and I’m sad that it’s happeing🥺', 'sentiment': 'negative', 'user_id': 1026447132755152897, 'name': 'Lauruhhhhhhhhh', 'location': '', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:53'}]
# 35
# [{'id': 1193408163023749120, 'text': '@eicarttracie https://t.co/9UOOTYoos7', 'sentiment': 'neutral', 'user_id': 871147813098237952, 'name': 'JanineBrewer16', 'location': 'California, USA', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:53'}]
# 36
# [{'id': 1193408162994343936, 'text': 'Did Toronto kill Tyson Barrie?', 'sentiment': 'neutral', 'user_id': 33932605, 'name': 'Coach_Tinnell87', 'location': 'Papillion,NE', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:53'}]
# 37
# [{'id': 1193408162218438657, 'text': '@cctv_idiots @koisonbusani @BaileyOliver', 'sentiment': 'negative', 'user_id': 1262751186, 'name': 'ajwazhere0528', 'location': 'England, United Kingdom', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:52'}]
# 38
# [{'id': 1193408161706893313, 'text': '@CodingMark @mortchad @Tesla @zubinanary Lol silent and deadly', 'sentiment': 'positive', 'user_id': 32887308, 'name': 'overclockthis', 'location': 'Tampa, FL', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:52'}]
# 39
# [{'id': 1193408161589411840, 'text': "Husky House sounds like a version of the bachelor I'd be on. https://t.co/LTZU5Tivyf", 'sentiment': 'neutral', 'user_id': 89800091, 'name': 'itspeterj', 'location': 'New York', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:52'}]
# 40
# [{'id': 1193408160515657728, 'text': '@JewelryName 💖💖', 'sentiment': 'neutral', 'user_id': 610950091, 'name': 'JenniferMlott', 'location': 'USA', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:52'}]
# 41
# [{'id': 1193408160062722048, 'text': 'Went outside late to take pictures, exactly 15 mins later I’m back inside because “I loOk sUSPiciouS” and the police send me back to my hotel..', 'sentiment': 'negative', 'user_id': 2568243819, 'name': 'twiceundefeated', 'location': 'Bronx, NY', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:52'}]
# 42
# [{'id': 1193408159454507008, 'text': '@ayh85 @thebigo713 @SportsCenter Did you just include the raiders ? Lol', 'sentiment': 'positive', 'user_id': 1173060588014116866, 'name': 'Ezra40009629', 'location': '', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:52'}]
# 43
# [{'id': 1193408158527639553, 'text': 'I’m having an roll my eyes &amp; SMH moment on twitter.', 'sentiment': 'neutral', 'user_id': 819483319, 'name': 'wayland_debbie', 'location': '', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:52'}]
# 44
# [{'id': 1193408158489690112, 'text': 'Welp I wanna get married to him https://t.co/yxpdCQaBZp', 'sentiment': 'positive', 'user_id': 178998169, 'name': '_wherestherum', 'location': 'the deep south', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:52'}]
# 45
# [{'id': 1193408158435176449, 'text': 'Literally my 40 something year old neighbors are bumping music and having a party while I’m over here working. \n\nNow I know how Elle Woods felt when she was studying for the LSAT during homecoming week 😭😭😭😭', 'sentiment': 'positive', 'user_id': 422411045, 'name': 'steveahn_', 'location': 'lost angeles | hollyweird', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:52'}]
# 46
# [{'id': 1193408158422749184, 'text': '@Extra_Celestial on god 🥺💓', 'sentiment': 'neutral', 'user_id': 2322275794, 'name': 'luxecydney', 'location': '', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:52'}]
# 47
# [{'id': 1193408156925194240, 'text': '@RINGIQ_Boxing I gotta see ot bro....i gotta see it....i feel you and i knw where you at with it but, I gotta see more from him an it cant be against so bull rushing hard puncher. We already knw whts going to happen. I wanna see him fight a pure boxer or a better boxer puncher then ill be happy', 'sentiment': 'positive', 'user_id': 522665028, 'name': 'dboywso', 'location': 'Fairfield, CA', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:51'}]
# 48
# [{'id': 1193408156673536000, 'text': 'HOW LONG WOULD IT TAKE ME TO WALK ACROSS THE UNITED STATES ALL ALONE #jimmyeatworld \n\nthe older i get, the more i love @jimmyeatworld. @ The Bluebird https://t.co/1inr4ncNKU', 'sentiment': 'positive', 'user_id': 74339296, 'name': 'carterseaton', 'location': 'rock n roll, usa', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:51'}]
# 49
# [{'id': 1193408156665143296, 'text': 'LMFAO sensitive side of twitter cannot be fr rn https://t.co/gcqgVMKTdg', 'sentiment': 'positive', 'user_id': 1723727052, 'name': 'joannnnax', 'location': 'corcoran, ca', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:51'}]
# 50
# [{'id': 1193408156594065410, 'text': 'Just the beginning coach. https://t.co/5HkJc0iAL2', 'sentiment': 'neutral', 'user_id': 4606676535, 'name': 'dhansen_7', 'location': 'Field ', 'retweet count': 0, 'favorite count': 0, 'time': '11/10/2019 06:00:51'}]

# %%
with open('emoji/emoji_final_join.json',encoding='utf-8') as f: 
    emoji_list = json.load(f)


def check_emoji(text):
    all_emoji = []
    polarity = 0
    
    for ele in emoji_list:
        if ele['emoji'] in text:
            all_emoji.append(ele['emoji'])
            polarity += ele['polarity']
    emojis = ''.join(all_emoji)
    
    if len(all_emoji) != 0:
        polarity = round(polarity/len(all_emoji))
        
    return emojis, polarity
            


for element in tweet_obj_list:
    emojis,polarity = check_emoji(element[0]['text'])
    element[0]['emoji'] = emojis
    element[0]['emoji_polarity'] = polarity

# %%
## writes to this  
with open('11-10.json', 'w', encoding='utf-8') as outfile:   
    json.dump(tweet_obj_list, outfile, ensure_ascii=False, indent=4, separators=(',', ': '))

# %%
with open('11-10.json',encoding='utf-8') as f:
    line = json.load(f)
    print(len(line))
# Out:
# 50
